# %%
# %run Funciones.ipynb
import pandas as pd
# Out:
# 1:"
# PROYECTO
# "
# 2:"
# COLONIA
# "
# 3:"
# SUPERFICIE
# "
# 4:"
# RECÁMARAS
# "
# 5:"
#  $ DESDE
# "

# %% [markdown]
# ### portal inmobiliario

# %%
portal_inmobiliario=get_df(get_text(["https://www.elportalinmobiliario.com.mx/desarrollos/yucatan"],"clc-info"))
pd.DataFrame(portal_inmobiliario)
# Out:
#                                        0  \
# 0                           Única Living
# 1                      Corazon de Tierra
# 2                  Piaro Tropical Living
# 3                              Madero 54
# 4                            Las Acacias
# 5                         Villas del Sol
# 6                                   Zena
# 7                           Las Américas
# 8                                 Arteva
# 9                Via Montejo Residencial
# 10                      Puerto Esmeralda
# 11                                 Andra
# 12                        Adamant Mérida
# 13                        Bocana Telchac
# 14                       Periferico 2.08
# 15                 Gran San Pedro Cholul
# 16                          Puerto Lindo
# 17                         Montejo Plaza
# 18                            Primaselva
# 19  Monumento Departamentos de Altabrisa
# 20                             Cittadela
# 21                                Quadra
# ...

# %% [markdown]
# ### Grupo Balam

# %%
balam = ['https://www.balamgroup.com.mx/']
for i in range(2,78):
    balam.append('https://www.balamgroup.com.mx/page/{0}/'.format(i))

# %%
pd.DataFrame(get_df(get_text(balam,"property-item clearfix")))
# Out:
#                                                      0 1   \
# 0    Barreto 562 Residencia en el Centro de Mérida ...
# 1        Daytona casas de playa frente al mar en venta
# 2         Casa Melliza Nortemerida residencia en venta
# 3           Palta 152 Lofts en Venta en Cholul, Mérida
# 4     Palta 152 Residencias en Venta en Cholul, Mérida
# 5                     Casas en Nortemérida en Preventa
# 6             Macora 86 residencias en venta en Mérida
# 7    Casa en venta colonia centro Mérida para remod...
# 8    Los Gaviones Lotes Residenciales En Venta En M...
# 9    Casa en Venta en Fraccionamiento Viladiu Cholu...
# 10         Privada Avenida Conkal Residencias en Venta
# 11             Cumbres Montebello residencias en Venta
# 12   Casa en Venta Esquina Avenida Comercial Norte ...
# 13   Residencias en Dzitya de una planta – Mirova M...
# 14   Inmueble para Escuela ubicado al Oriente de Mé...
# 15        Bocamar Departamentos en Venta Frente al Mar
# ...

# %% [markdown]
# ### Anah

# %%
nombre=pd.DataFrame(get_text(["https://www.a-nah.com/invierte-en/merida#nuestros-desarrollos"],"titulosdesarrolloslist"))
loc=pd.DataFrame(get_text(["https://www.a-nah.com/invierte-en/merida#nuestros-desarrollos"],"subtitulosdesarrolloslist"))
summary=pd.DataFrame(get_text(["https://www.a-nah.com/invierte-en/merida#nuestros-desarrollos"],"summarydesarrollos"))
price=pd.DataFrame(get_text(["https://www.a-nah.com/invierte-en/merida#nuestros-desarrollos"],"featuredtextprice"))

# %%
pd.concat([nombre,loc,summary,price], axis=1)
# Out:
#                             0       0  \
# 0          Kinish Residencial  Merida
# 1      Barlovento Residencial  Merida
# 2  Kinish Residencial - Casas  Merida
# 3              Torre Catalina  Merida
# 4            Parque Tixpehual  Merida
#
#                                                    0  \
# 0  Residencial de 136 lotes ubicado en el área de...
# 1  Residencial de 20 casas ubicada en Temozón Nor...
# 2  4 exclusivas unidades dentro de un complejo re...
# 3  Torre de 24 departamentos ubicado en Montebell...
# 4  Lotes industriales ubicados en el área de Tixp...
#
#                                          0
# 0                       Desde $900,000 MXN
# 1       Casas Residenciales $3,580,000 MXN
# 2       Casas residenciales $3,100,000 MXN
# 3          Último penthouse $5,600,000 MXN
# 4  Lotes industriales desde $1,593,000 MXN

# %% [markdown]
# ### AMG

# %%
pd.DataFrame(get_df(get_text(['https://www.amg.mx/desarrollos'],"span4")))
# Out:
#                            0  \
# 0       DESARROLLOS ACTUALES
# 1           Alba Residencial
# 2  Siara Privada Residencial
# 3  Alera Privada Residencial
# 4  Zensia Parque Residencial
#
#                                                    1                      2  \
# 0                                               None                   None
# 1  Alba se localiza en Conkal, al norte de Mérida...  Conocer el desarrollo
# 2  Exclusivo complejo residencial diseñado con he...  Conocer el desarrollo
# 3  Exclusivo desarrollo residencial con viviendas...  Conocer el desarrollo
# 4  Zensia es el resultado de una perfecta integra...  Conocer el desarrollo
#
#         3                 4
# 0    None              None
# 1  Conkal  Desde $2,865,000
# 2  Dzityá  Desde $2,110,000
# 3  Dzityá  Desde $2,280,000
# 4  Conkal  Desde $1,616,000

# %% [markdown]
# ### Royal Inmobiliaria

# %%
pd.DataFrame(get_df(get_text(['https://royalinmobiliaria.com.mx/desarrollos-residenciales-norte-merida/'],"col-lg-4 order-1 order-md-0")))
# Out:
#             0                                                  1 2  \
# 0   Monumento  Departamentos en Venta en Altabrisa, ideales p...
# 1  Campocielo  Casas y Lofts en venta en Mérida ubicados  en ...
#
#                     3
# 0  Conocer desarrollo
# 1  Conocer desarrollo

# %% [markdown]
# ### BR Yucatan

# %%
pd.DataFrame(get_df(get_text(['https://www.bryucatan.com.mx/Desarrollos'],"prop_data")))
# Out:
#                       0                          1  \
# 0      Yucatán , México                    Tapiola
# 1      Mérida , Yucatán  PARQUE NATURA RESIDENCIAL
# 2      Mérida , Yucatán                    Alessia
# 3      Mérida , Yucatán                     CIERZO
# 4      Mérida , Yucatán                ALTO VIENTO
# 5      Mérida , Yucatán         PRIVADA SANTA CRUZ
# 6      Mérida , Yucatán                   SIMARUBA
# 7      Mérida , Yucatán                       LOMA
# 8      Mérida , Yucatán                      ÚNICA
# 9      Mérida , Yucatán                     MAKENA
# 10     Mérida , Yucatán                     OLIVOS
# 11     Mérida , Yucatán                 TAMARINDOS
# 12     Mérida , Yucatán                AGUA NATIVA
# 13     Yucatán , México           PARQUE TIXPEHUAL
# 14     Mérida , Yucatán                 BARLOVENTO
# 15     Mérida , Yucatán                 COMPOSTELA
# 16     Yucatán , México                     TAMORA
# ...

# %% [markdown]
# ### ORTEN

# %%
pd.DataFrame(get_df(get_text(['https://www.orten.com.mx/Desarrollos'],"prop_data")))
# Out:
#                    0                               1   \
# 0    Conkal , Yucatán       Privada Residencial Aleza
# 1    Conkal , Yucatán                 Botánico Conkal
# 2    Yucatán , México           Residencial Ya'ax Beh
# 3    Mérida , Yucatán                          Maculi
# 4    Mérida , Yucatán                Privada Abedules
# 5    Mérida , Yucatán  Norte Mérida (quedan 23 lotes)
# 6    Mérida , Yucatán                       Albarella
# 7    Yucatán , México       Zensia Parque Residencial
# 8  Progreso , Yucatán             Puerto Lindo Chelem
#
#                                                   2   \
# 0                   Privada Residencial Aleza Conkal
# 1                   Botánico Conkal, Entorno Natural
# 2                   ¡PRIVADA RESIDENCIAL  Ya'ax Beh!
# 3  Privada de hermosas casas tipo townhous en Cholul
# 4                   Privada Abedules- Parque central
# 5                    Pueblo de Komchen en la entrada
# ...

# %% [markdown]
# ### SANTOS

# %%
pd.DataFrame(get_df(get_text(['http://www.santosinmobiliaria.com.mx/'],"development-item")))
# Out:
#                                                     0
# 0   Próximamanete     Descubre más en cittadela.co...
# 1   36 vendido     Descubre más en vivemalva.com  ...
# 2   70 vendido     Descubre más en vivezena.com   ...
# 3   45 vendido     Descubre más en viveolivia.com ...
# 4   14 vendido     Descubre más en vivearteva.com ...
# 5   Próximamanete     Descubre más en panorama336....
# 6   100 vendido     Descubre más en santosinmobili...
# 7   100 vendido     Descubre más en santosinmobili...
# 8   100 vendido     Descubre más en santosinmobili...
# 9   100 vendido     Descubre más en santosinmobili...
# 10  90 vendido     Descubre más en vivearborea.com...
# 11  100 vendido     Descubre más en vivejulieta.co...
# 12  100 vendido     Descubre más en santosinmobili...
# 13  100 vendido     Descubre más en santosinmobili...
# 14  100 vendido     Descubre más en vivesilvano.co...
